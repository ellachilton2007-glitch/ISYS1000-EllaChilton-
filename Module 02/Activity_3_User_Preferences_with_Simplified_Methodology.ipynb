# %% [markdown]
# <a href="https://colab.research.google.com/github/ellachilton2007-glitch/ISYS1000-EllaChilton-/blob/main/Module%2002/Activity_3_User_Preferences_with_Simplified_Methodology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Activity 3: User Preferences with Simplified Methodology
#
# ## Learning Outcome
#
# Apply a structured problem-solving methodology to design and build a User Preferences program. You will practise computational thinking by breaking the problem into manageable steps, from planning and pseudocode through to coding your final solution, and you will learn how to use AI tools to support your process.
#
# > **Note:** This activity is about the workflow and process of solving a problem, not the problem itself. The task is similar to Activity 2, but here you follow a structured method. As you go, notice how planning first changes the way the coding feels compared with the ad-hoc approach in Activity 2.
#
# Work through the six steps in order, completing each **Your turn** cell before moving on.

# %% [markdown]
# ---
#
# ## Step 1: State the Problem
#
# **What to do:** In your own words, write down what your program should achieve. No code yet.
#
# **Example:**
# - **Goal:** Build a program that collects several user preferences and displays them in a clear, personalised summary.
# - **Consider:** What information should it gather (for example name, favourite colour, favourite food, hobby)? How should it present that back (for example a friendly summary message)?
#
# > **AI Tip:** Use an AI tool to help you rephrase your description. For example, ask: "Can you restate my description of a user preferences program to check I have captured the intent?" Then confirm the answer only uses what you have learned so far: `input()`, `print()`, basic data types, and variables.
#
# ---

# %% [markdown]
# ### Your turn
#
# I am going to build a program that collects serveral different user preferences including the users name, height, age, favourite colour and how many siblings they have. I will then clearly display this information in a personalised summary.

# %% [markdown]
# ## Step 2: Describe Input and Output
#
# **What to do:** List the information your program will ask for (the inputs), and write the exact summary message you want it to print (the output).
#
# **Example:**
# - **Inputs:** name, favourite colour, favourite food, favourite hobby.
# - **Output:** a message like:
#   > "Hello, [name]! Your favourite colour is [colour], you love [food], and you enjoy [hobby]."
#
# > **Tip:** Mapping inputs to the expected output helps you picture the whole flow before you code.
#
# > **AI Tip:** Ask an AI tool, "What are some creative ways to format a user preferences summary?" and check the answer only uses concepts you have learned so far.

# %% [markdown]
# ### Your turn
# My inputs: Name , Height , Age , Favourite Colour & Number of siblings
#
# My expected output: Hi (Name)!
#                     Your height is (Height) CM tall, you are (age) years old with (number of siblings) siblings and your favourite colour is (favourite colour).

# %% [markdown]
# ---
#
# ## Step 3: Work the Problem by Hand
#
# **What to do:** Before writing code, pretend you are the computer. Pick sample answers and write out exactly what the program should print for them. This becomes your test case.
#
# **Example:** for a user named "Alice" who chooses colour Blue, food Pasta, and hobby Reading, the program should print:
# > "Hello, Alice! Your favourite colour is Blue, you love Pasta, and you enjoy Reading."
#
# > **Tip:** Try a couple of different sample answers to be sure your plan is clear.
#
# > **AI Tip:** If you are unsure about your expected output, ask an AI tool, "Does this output message clearly reflect the inputs provided?"
#
# ---

# %% [markdown]
# ### Your turn
# My sample answers: Name = Ella , Height = 171cm , Age 19 , Siblings = 1 , Favourite colour = red
#
# Expected output: Hi Ella! Your height is 171 cm tall, you are 19 years old with 1 siblings and your favourite colour is red.

# %% [markdown]
# ---
#
# ## Step 4: Develop an Algorithm (Pseudocode)
#
# **What to do:** Turn your plan into pseudocode, the logical steps written in plain language. It does not need to be valid Python.
#
# **Example:**
#
# ```plain
# 1. Start the program.
# 2. Prompt the user for their name and store it.
# 3. Prompt for their favourite colour and store it.
# 4. Prompt for their favourite food and store it.
# 5. Prompt for their favourite hobby and store it.
# 6. Build a summary message from the stored inputs.
# 7. Print the summary message.
# 8. End the program.
# ```
#
# > **Tip:** Your pseudocode does not need to follow Python syntax. It just outlines the logical steps.
#
# > **AI Tip:** Ask an AI tool, "Can you check my pseudocode for a user preferences program and suggest improvements?" Keep the suggestions within what you have learned so far (no functions or f-strings yet).

# %%
# STEP 4: Your pseudocode
# Pseudocode is your plan in plain language. It does not need to run.
# Edit the lines below to match your own plan.

# 1. Start the program.
# 2. Prompt the user for their name.
# 3. Prompt the user for their height.
# 4. Prompt the user for their age.
# 5. Prompt the user for the number of siblings they have.
# 6. Prompt the user for their favourite colour.
# 7. Build a summary message from the stored input.
# 8. Print the summary message.
# 9. End the program.

# %% [markdown]
# ---
#
# ## Step 5: Write the Code
#
# **What to do:** Now turn your pseudocode into real Python, using only `input()`, `print()`, variables, and basic operations. Below is one example solution. Run it, then compare it line by line with the pseudocode you wrote.

# %%
name = input("What is your name? ")
height = input("How tall are you in cm? ")
birth_year = int(input("what year were you born in? "))
import datetime
current_year = datetime.datetime.now().year
age = current_year - birth_year
siblings = input("How many siblings do you have? ")
favourite_colour = input("What's your favourite colour? ")



# Construct and display a personalised summary message
print("\nHello, " + name + "!")
print("Your height is " + height + "cm tall, you are " + str(age) + " years old with " + siblings + " siblings and your favourite colour is " + favourite_colour + ".")
# Out:
# What is your name? Ella
# How tall are you in cm? 171
# what year were you born in? 2007
# How many siblings do you have? 1
# What's your favourite colour? Red
#
# Hello, Ella!
# Your height is 171cm tall, you are 19 years old with 1 siblings and your favourite colour is Red.

# %% [markdown]
# > **Tip:** Run the cell above to test your program and check your inputs are captured and displayed correctly.
#
# ---
#
# ## Mini-Challenges
#
# These optional challenges extend your program. Try to write each one yourself. The commented lines are hints, not the finished answer.
#
# ### Challenge 1: Starred preferences
#
# **What to do:** Change your output so each preference prints on its own line, starting with a star (`*`).
#
# > **Hint:** Use the newline character `\n` in your string, or print each line separately.

# %%
# Your turn: print each preference on its own line, starting with a star.
# One way to start:

# print("* Name:", name)
# print("* Favourite Colour:", favourite_colour)
# print("* Favourite Food:", favourite_food)
# print("* Favourite Hobby:", favourite_hobby)

# Your code here:

# %% [markdown]
# ### Challenge 2: Age calculator
#
# **What to do:** Ask the user for their birth year, work out their age for the current year, and print it.
#
# > **Hint:** `input()` returns text, so convert the birth year with `int()` before doing the maths. You may use the `datetime` module to get the current year. If it is new to you, ask an AI tutor for a simple step-by-step explanation.

# %%
# Your turn: ask for a birth year and calculate the user's age.
# One way to start:

# import datetime
# birth_year = int(input("What year were you born? "))
# current_year = datetime.datetime.now().year
# age = current_year - birth_year
# print("You are", age, "years old!")

# Your code here:

# %% [markdown]
# ### Challenge 3 (optional, advanced): f-string formatting
#
# **What to do:** Rewrite your summary message using an f-string for cleaner syntax. This one is optional and goes a little beyond this week. If f-strings are new to you, ask for a beginner-friendly explanation first.

# %%
# Your turn (optional): rewrite the summary using an f-string.
# One way to start:

# print(f"Hello, {name}! Your favourite colour is {favourite_colour}, you love {favourite_food}, and you enjoy {favourite_hobby}.")

# Your code here:

# %% [markdown]
# > **AI Tip:** For each challenge, ask focused questions like "How do I print multiple lines in Python?" or "What is an f-string and how do I use it?" Follow up on anything that is unclear.
#
# ---
#
# ## Reflection and Next Steps
#
# Compare your experience of Activity 2 (the ad-hoc approach) with Activity 3 (the structured approach). Did planning with pseudocode first make the coding feel faster or easier? How was the process different?
#
# - What did you find most helpful about planning before coding?
# - Did working through the pseudocode make the coding step easier?
# - Which mini-challenge did you enjoy most, and why?
# - How did AI tools help you clarify the problem or refine your approach?
#
# > **General AI Usage Tip:** If an AI tool suggests something not yet covered (like exceptions, imports, user-defined functions, or f-strings), ask it to redo the answer using only what you have learned so far: `input()`, `print()`, basic data types, and variables. Always check the output against your own understanding.
#
# **Next steps:**
# - Experiment by adding more preferences or changing the output format.
# - Share your approach with peers and compare solutions.
# - Keep using AI as a resource, asking follow-up questions on anything you do not understand.
#
# Happy coding, and enjoy turning your plan into a working program!
